# %%
import requests 
import json
import pandas as pd
import re
import spacy
import numpy as np
import scipy
from sklearn.cluster import KMeans
from spacy.lang.de.examples import sentences 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
import de_core_news_sm
from operator import itemgetter

# %%
pip install azure-ai-textanalytics==5.1.0
# Out:
# Requirement already satisfied: azure-ai-textanalytics==5.1.0 in c:\programdata\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\anaconda3\lib\site-packages (from azure-ai-textanalytics==5.1.0) (1.1.28)
# Requirement already satisfied: azure-core<2.0.0,>=1.14.0 in c:\programdata\anaconda3\lib\site-packages (from azure-ai-textanalytics==5.1.0) (1.24.0)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from azure-ai-textanalytics==5.1.0) (1.15.0)
# Requirement already satisfied: msrest>=0.6.21 in c:\programdata\anaconda3\lib\site-packages (from azure-ai-textanalytics==5.1.0) (0.6.21)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics==5.1.0) (4.2.0)
# Requirement already satisfied: requests>=2.18.4 in c:\programdata\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics==5.1.0) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-textanalytics==5.1.0) (2020.12.5)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-textanalytics==5.1.0) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-textanalytics==5.1.0) (1.3.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics==5.1.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics==5.1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics==5.1.0) (1.26.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-textanalytics==5.1.0) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# %%
key = "c09dde90c9f34da3b69065aabdb735c8"
endpoint = "https://berlinbobbi.cognitiveservices.azure.com/"

# %%
def authenticate_client(key, endpoint):
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

# %%
client = authenticate_client()

# %%
nlp = spacy.load('de_core_news_lg')

# %%
def get_json_from_solr(query, max_elems):
    query = query.replace(' ', '%20')
    url = f"http://localhost:8983/solr/d115Services/select?indent=true&q.op=OR&q=*{query}*&rows={max_elems}"
    return requests.get(url).json()

# %%
def get_df_from_json(json_file):
    data = json_file["response"]["docs"]
    return pd.DataFrame.from_dict(data)

# %%
df_res["ssdsLemma"]
# Out:
# 0     [anwohnerpark, fußgängerzone, anwohnerparkausw...
# 1     [angehörig, pflege, parkausweis, pflegen, gast...
# 2     [erteilung, handwerkerparkausweis, betreiben, ...
# 3     [perser, personalausweisverlust, ausweisverlus...
# 4     [mensch, rundfunk-, merkzeichen, eigenschaft, ...
# 5     [personalausweisverlust, reisedokument, ersatz...
# 6     [gehbehinderung, parkausweis, parkerlaubnis, a...
# 7     [perso, personalausweisangelegenheit, beantrag...
# 8     [ausweisantrag, eid, beantragung, ausstellen, ...
# 9     [online-ausweisfunktion, perso, eid, elektroni...
# 10    [perser, perso, ausweispflicht, elektronisch, ...
# 11    [ausland, ewr, berufsausweis, europäisch, kran...
# 12    [kfz-steuer, wertmark, merkzeichen, fahrmarke,...
# 13    [beschädigt, merkzeichen, handycap, stehlen, p...
# 14    [übertragen, pass, aufenthaltserlaubnis-schwei...
# 15    [ausstellung, deutsche, bestehen, -, nachweis,...
# 16    [wertmark, behinderung, wertmarke, ausstellung...
# 17    [wohnsitz, ersatzausweis, künstlername, finger...
# 18    [eid, bundeseinheitliches, aktivierung, später...
# 19    [online-ausweisfunktion, eid, ewr, elektronisc...
# 20    [perser, eid, bundeseinheitliches, setzen, puk...
# 21    [online-ausweisfunktion, eid, ewr, elektronisc...
# 22    [wohnsitz, sein, vorläufig, obdachlos, wohnung...
# 23    [haus-, fluglärm, lärmanzeigen, lärmanzeige, u...
# 24    [lagebezeichnung, beleuchten, hinweisschild, g...
# 25    [grundstücksnummer, hausnummer, grundstücksnum...
# 26    [auskunft, kraftfahrzeug, fachauskunft, in, kf...
# 27    [ausgesetzte, zugelaufen, herrenlose, aussetze...
# 28    [hausmüll, müllabfuhr, entsorgung, müllabfahre...
# 29    [bußgeld, zahlung, der, kontonummer, haushalts...
# 30    [hilfe, weiterführung, pflege, pflegen, sozial...
# 31    [peep-show, erlaubnis, gewerbsmäßigen, polen, ...
# 32    [ifsg, brunnen, wasserwerk, trinkwasserverordn...
# Name: ssdsLemma, dtype: object

# %%
def clean_df(df):
    df = df[["id", "d115Url", "d115Name", "ssdsLemma", "d115Description"]]
    df.columns = ["id", "url", "name", "lemmas", "description"]
    df["to_cluster"] = df.apply(lambda row: re.sub("<[^<]+?>", " "," ".join(row.lemmas)).replace("\n", " "), axis=1)
    return df

# %%
def preprocess_text(text, nlp_model):
    doc = nlp_model(text)
    return " ".join([tok.lemma_ for tok in doc if not tok.is_stop and not tok.is_punct and not tok.is_space])

# %%
def get_clusters(df):
    vectorizer = TfidfVectorizer()
    clustering = DBSCAN(eps=1.38, min_samples=1)
    vectors = vectorizer.fit_transform(df_res["lemmas"].tolist())
    clusters = clustering.fit(vectors).labels_
    df["cluster"] = clusters
    return df

# %%
def get_kmeans_clust(df,k):
    kvectorizer = TfidfVectorizer()
    kvector = kvectorizer.fit_transform(df['lemmas'].tolist())
    Kmodel = KMeans(n_clusters=k,init='k-means++',max_iter=100,n_init=1)
    Kmodel.fit(kvector)
    df["Kcluster"] = Kmodel.labels_
    return df

# %%
def group_by_cluster(df):
    df_work = df[['lemmas','cluster']]
    df_work=df_work.groupby(['cluster'])['lemmas'].apply(lambda x: ' '.join(x)).reset_index()
    return df_work

# %%
def return_topics(df,n=1):
    vectorizer=TfidfVectorizer()
    rows = vectorizer.fit_transform(df['lemmas'].tolist()).toarray()
    features=vectorizer.get_feature_names()
    i=0
    topics=[]
    while i<len(rows):
        top_feats=[]
        topn_ids = np.argsort(rows[i])[::-1][:n]
        top_feats = [(features[j]) for j in topn_ids]
        topics.append(top_feats)
        i+=1
    df['Topics']=topics
    return df

# %%
def topics_to_service(df_res,df_clus):
    df_res["topic"]=df_res.apply(lambda row: df_clus.iloc[df_res.iloc[row.name,6],2], axis=1)
    return df_res

# %%
def categorize_text(df,):
    topic=[None]*len(df)
    i=0
    while i<len(df):    
        documents=[df['lemmas'].iloc[i]]
        result =client.recognize_entities(documents)[0]
        summary=[]
        for entity in result.entities:
            categorized=[entity.text,entity.category,round(entity.confidence_score,2),entity.offset]
            summary.append(categorized)
        topic[i]=(sorted(summary,key=itemgetter(2),reverse=False))
        i+=1
    df['categorized']=topic
    return df

# %%
json_file=get_json_from_solr('antrag', 1000)
df_res = get_df_from_json(json_file)
df_res = clean_df(df_res)
df_res["lemmas"] = df_res.apply(lambda row: preprocess_text(row.ssdsLemmas, nlp), axis=1)
df_res = get_clusters(df_res)
print(df_res)
# Out:
# <ipython-input-7-7bb5ed22cbbd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ssdsLemmas"] = df.apply(lambda row: re.sub("<[^<]+?>", " "," ".join(row.ssdsLemmas)).replace("\n", " "), axis=1)
#         id                                               url  \
# 0   120656  https://service.berlin.de/dienstleistung/120656/
# 1   120665  https://service.berlin.de/dienstleistung/120665/
# 2   318993  https://service.berlin.de/dienstleistung/318993/
# 3   324703  https://service.berlin.de/dienstleistung/324703/
# 4   325685  https://service.berlin.de/dienstleistung/325685/
# 5   326003  https://service.berlin.de/dienstleistung/326003/
# 6   326235  https://service.berlin.de/dienstleistung/326235/
# 7   326952  https://service.berlin.de/dienstleistung/326952/
# 8   327098  https://service.berlin.de/dienstleistung/327098/
# 9   327661  https://service.berlin.de/dienstleistung/327661/
# 10  328020  https://service.berlin.de/dienstleistung/328020/
# 11  328050  https://service.berlin.de/dienstleistung/328050/
# 12  328469  https://service.berlin.de/dienstleistung/328469/
# 13  329250  https://service.berlin.de/dienstleistung/329250/
# 14  329295  https://service.berlin.de/dienstleistung/329295/
# 15  329307  https://service.berlin.de/dienstleistung/329307/
# 16  329316  https://service.berlin.de/dienstleistung/329316/
# 17  329322  https://service.berlin.de/dienstleistung/329322/
# 18  329394  https://service.berlin.de/dienstleistung/329394/
# 19  329905  https://service.berlin.de/dienstleistung/329905/
#
#                                                  name  \
# 0                  Wohngeld - Mietzuschuss beantragen
# 1                Wohngeld - Lastenzuschuss beantragen
# 2   Ehefähigkeitszeugnis – Beratung, Antrag,  Auss...
# 3   Vereinigungs- und Teilungsanträge (Grundstücke...
# 4   Einkommensteuer - Festsetzung - Antragsveranla...
# 5           Sozialversicherung - Rentenantrag stellen
# 6   Antragsbescheinigung für Familienangehörige vo...
# 7                     Scheidungsantrag - Entscheidung
# 8   Vollstreckungsschutzantrag, Spezialfall Räumun...
# 9   Insolvenzverfahren - Regelinsolvenz - Geschäft...
# 10  Tätigkeiten mit Krankheitserregern - Beantragu...
# 11   Prostitutionsgewerbe - Erlaubnis für den Betrieb
# 12          Staatsangehörigkeitsausweis - Ausstellung
# 13  Denkmal - Bescheinigung für Denkmalerhalt nach...
# 14              Kanzleipflicht - Antrag auf Befreiung
# 15  Europäischer Rechtsanwalt - Antrag auf Aufnahm...
# 16          Rechtsanwaltschaft - Antrag auf Zulassung
# 17  Rechtsanwaltschaft - Antrag auf Aufnahme als A...
# 18  Handwerk – Löschung aus der Handwerksrolle, de...
# 19  Versteigerergewerbe - Öffentliche Bestellung u...
#
#                                            ssdsLemmas  \
# 0   wohngeld mieten mietzuschuss wohnhilfe lastenz...
# 1   wohngeld mieten eigenheimhilfe lastenzuschuss ...
# 2   ausland heirat im ledigkeitsnachweis ausstellu...
# 3   liegenschaftskatasterauskunft grundstücksberei...
# 4   elektronisch elektronsiche einkommensteuertabe...
# 5   eu-rente rentenantrag schwerbehindertenrente d...
# 6   freizügigkeitsrecht ewr aufenthaltskarte freiz...
# 7   ehe rechtsanwaltszwang ehescheidung scheidung ...
# 8   vollstreckungsschutz maßnahme räumungsschutzan...
# 9   geschäftsbetrieb firmeninsolvenz unternehmensi...
# 10  44 infektionserregerdiagnostik erlaubnis beant...
# 11  erlaubnis swingerclub prostschg bordell prosti...
# 12  ausstellung deutsche bestehen - nachweis fests...
# 13  steuerlich denkmalerhalten förderprogramm denk...
# 14  kanzleipflicht zulassung bundesrechtsanwaltsor...
# 15  deutschland in zulassung europäisch tätigkeit ...
# 16  erteilung auf zulassung zur rechtsanwaltschaft...
# 17  erteilung zulassung § als ein - aufnahme angeh...
# 18  modist pinselmacher holzblasinstrumentenmacher...
# 19  vereidigt versteigerergewerbe notverkauf sachv...
#
#                                           description  \
# 0   Wohngeld kann Ihnen angemessenes und familien-...
# 1   Wohngeld kann Ihnen angemessenes und familien-...
# 2   Sie haben die deutsche Staatsangehörigkeit und...
# 3   Grundstücke als räumlich zusammenhängende wirt...
# 4   <strong>Antragsveranlagung</strong><br />\n<br...
# 5   Die gesetzliche Rentenversicherung ist ein Tei...
# 6   <strong>Bitte beachten Sie</strong>: Diese Die...
# 7   Eine Ehe kann durch das Familiengericht geschi...
# 8   In ganz besonderen Ausnahmefällen können Sie s...
# 9   Das Insolvenzverfahren über einen Geschäftsbet...
# 10  Für die Tätigkeit mit Krankheitserregern wird ...
# 11  Wer ein Prostitutionsgewerbe betreibt, benötig...
# 12  Sie sind Deutsche oder Deutscher und benötigen...
# 13  Denkmaleigentümer können für Aufwendungen an i...
# 14  Grundsätzlich besteht die Pflicht eine Kanzlei...
# 15  Für Personen aus Staaten, die Mitglied der Eur...
# 16  Die Berufsbezeichnungen Rechtsanwalt/Rechtsanw...
# 17  Anwälte/Anwältinnen aus Staaten außerhalb der ...
# 18  Wenn Sie Ihren Eintrag in der Handwerksrolle o...
# 19  Wenn Sie öffentliche Versteigerungen (zwangswe...
#
#                                                lemmas  cluster
# 0   Wohngeld mieten Mietzuschuss Wohnhilfe Lastenz...        0
# 1   Wohngeld mieten Eigenheimhilfe Lastenzuschuss ...        0
# 2   Ausland Heirat Ledigkeitsnachweis Ausstellung ...        0
# 3   liegenschaftskatasterauskunft Grundstücksberei...        1
# 4   elektronisch elektronsich einkommensteuertabel...        2
# 5   eu-rente Rentenantrag schwerbehindertenrent dr...        0
# 6   Freizügigkeitsrecht ewr aufenthaltskart Freizü...        0
# 7   -- Rechtsanwaltszwang Ehescheidung Scheidung S...        3
# 8   Vollstreckungsschutz Maßnahme Räumungsschutzan...        4
# 9   Geschäftsbetrieb Firmeninsolvenz Unternehmensi...        5
# 10  44 Infektionserregerdiagnostik Erlaubnis Beant...        0
# 11  Erlaubnis Swingerclub Prostschg Bordell Prosti...        6
# 12  Ausstellung deutsch bestehen Nachweis Feststel...        0
# 13  steuerlich denkmalerhalt Förderprogramm Denkma...        0
# 14  Kanzleipflicht Zulassung Bundesrechtsanwaltsor...        0
# 15  Deutschland Zulassung europäisch Tätigkeit Auf...        0
# 16  Erteilung Zulassung Rechtsanwaltschaft Rechtsa...        0
# 17  Erteilung Zulassung Aufnahme angehöriger Brao ...        0
# 18  Modist Pinselmacher Holzblasinstrumentenmacher...        7
# 19  vereidigen versteigerergewerbe notverkauf sach...        8

# %%
df_top=group_by_cluster(df_res)
df_top=return_topics(df_top,3)
df_res=topics_to_service(df_res,df_top)
print(df_res)
# Out:
#         id                                               url  \
# 0   120656  https://service.berlin.de/dienstleistung/120656/
# 1   120665  https://service.berlin.de/dienstleistung/120665/
# 2   318993  https://service.berlin.de/dienstleistung/318993/
# 3   324703  https://service.berlin.de/dienstleistung/324703/
# 4   325685  https://service.berlin.de/dienstleistung/325685/
# 5   326003  https://service.berlin.de/dienstleistung/326003/
# 6   326235  https://service.berlin.de/dienstleistung/326235/
# 7   326952  https://service.berlin.de/dienstleistung/326952/
# 8   327098  https://service.berlin.de/dienstleistung/327098/
# 9   327661  https://service.berlin.de/dienstleistung/327661/
# 10  328020  https://service.berlin.de/dienstleistung/328020/
# 11  328050  https://service.berlin.de/dienstleistung/328050/
# 12  328469  https://service.berlin.de/dienstleistung/328469/
# 13  329250  https://service.berlin.de/dienstleistung/329250/
# 14  329295  https://service.berlin.de/dienstleistung/329295/
# 15  329307  https://service.berlin.de/dienstleistung/329307/
# 16  329316  https://service.berlin.de/dienstleistung/329316/
# 17  329322  https://service.berlin.de/dienstleistung/329322/
# 18  329394  https://service.berlin.de/dienstleistung/329394/
# 19  329905  https://service.berlin.de/dienstleistung/329905/
#
#                                                  name  \
# 0                  Wohngeld - Mietzuschuss beantragen
# 1                Wohngeld - Lastenzuschuss beantragen
# 2   Ehefähigkeitszeugnis – Beratung, Antrag,  Auss...
# 3   Vereinigungs- und Teilungsanträge (Grundstücke...
# 4   Einkommensteuer - Festsetzung - Antragsveranla...
# 5           Sozialversicherung - Rentenantrag stellen
# 6   Antragsbescheinigung für Familienangehörige vo...
# 7                     Scheidungsantrag - Entscheidung
# 8   Vollstreckungsschutzantrag, Spezialfall Räumun...
# 9   Insolvenzverfahren - Regelinsolvenz - Geschäft...
# 10  Tätigkeiten mit Krankheitserregern - Beantragu...
# 11   Prostitutionsgewerbe - Erlaubnis für den Betrieb
# 12          Staatsangehörigkeitsausweis - Ausstellung
# 13  Denkmal - Bescheinigung für Denkmalerhalt nach...
# 14              Kanzleipflicht - Antrag auf Befreiung
# 15  Europäischer Rechtsanwalt - Antrag auf Aufnahm...
# 16          Rechtsanwaltschaft - Antrag auf Zulassung
# 17  Rechtsanwaltschaft - Antrag auf Aufnahme als A...
# 18  Handwerk – Löschung aus der Handwerksrolle, de...
# 19  Versteigerergewerbe - Öffentliche Bestellung u...
#
#                                            ssdsLemmas  \
# 0   wohngeld mieten mietzuschuss wohnhilfe lastenz...
# 1   wohngeld mieten eigenheimhilfe lastenzuschuss ...
# 2   ausland heirat im ledigkeitsnachweis ausstellu...
# 3   liegenschaftskatasterauskunft grundstücksberei...
# 4   elektronisch elektronsiche einkommensteuertabe...
# 5   eu-rente rentenantrag schwerbehindertenrente d...
# 6   freizügigkeitsrecht ewr aufenthaltskarte freiz...
# 7   ehe rechtsanwaltszwang ehescheidung scheidung ...
# 8   vollstreckungsschutz maßnahme räumungsschutzan...
# 9   geschäftsbetrieb firmeninsolvenz unternehmensi...
# 10  44 infektionserregerdiagnostik erlaubnis beant...
# 11  erlaubnis swingerclub prostschg bordell prosti...
# 12  ausstellung deutsche bestehen - nachweis fests...
# 13  steuerlich denkmalerhalten förderprogramm denk...
# 14  kanzleipflicht zulassung bundesrechtsanwaltsor...
# 15  deutschland in zulassung europäisch tätigkeit ...
# 16  erteilung auf zulassung zur rechtsanwaltschaft...
# 17  erteilung zulassung § als ein - aufnahme angeh...
# 18  modist pinselmacher holzblasinstrumentenmacher...
# 19  vereidigt versteigerergewerbe notverkauf sachv...
#
#                                           description  \
# 0   Wohngeld kann Ihnen angemessenes und familien-...
# 1   Wohngeld kann Ihnen angemessenes und familien-...
# 2   Sie haben die deutsche Staatsangehörigkeit und...
# 3   Grundstücke als räumlich zusammenhängende wirt...
# 4   <strong>Antragsveranlagung</strong><br />\n<br...
# 5   Die gesetzliche Rentenversicherung ist ein Tei...
# 6   <strong>Bitte beachten Sie</strong>: Diese Die...
# 7   Eine Ehe kann durch das Familiengericht geschi...
# 8   In ganz besonderen Ausnahmefällen können Sie s...
# 9   Das Insolvenzverfahren über einen Geschäftsbet...
# 10  Für die Tätigkeit mit Krankheitserregern wird ...
# 11  Wer ein Prostitutionsgewerbe betreibt, benötig...
# 12  Sie sind Deutsche oder Deutscher und benötigen...
# 13  Denkmaleigentümer können für Aufwendungen an i...
# 14  Grundsätzlich besteht die Pflicht eine Kanzlei...
# 15  Für Personen aus Staaten, die Mitglied der Eur...
# 16  Die Berufsbezeichnungen Rechtsanwalt/Rechtsanw...
# 17  Anwälte/Anwältinnen aus Staaten außerhalb der ...
# 18  Wenn Sie Ihren Eintrag in der Handwerksrolle o...
# 19  Wenn Sie öffentliche Versteigerungen (zwangswe...
#
#                                                lemmas  cluster  \
# 0   Wohngeld mieten Mietzuschuss Wohnhilfe Lastenz...        0
# 1   Wohngeld mieten Eigenheimhilfe Lastenzuschuss ...        0
# 2   Ausland Heirat Ledigkeitsnachweis Ausstellung ...        0
# 3   liegenschaftskatasterauskunft Grundstücksberei...        1
# 4   elektronisch elektronsich einkommensteuertabel...        2
# 5   eu-rente Rentenantrag schwerbehindertenrent dr...        0
# 6   Freizügigkeitsrecht ewr aufenthaltskart Freizü...        0
# 7   -- Rechtsanwaltszwang Ehescheidung Scheidung S...        3
# 8   Vollstreckungsschutz Maßnahme Räumungsschutzan...        4
# 9   Geschäftsbetrieb Firmeninsolvenz Unternehmensi...        5
# 10  44 Infektionserregerdiagnostik Erlaubnis Beant...        0
# 11  Erlaubnis Swingerclub Prostschg Bordell Prosti...        6
# 12  Ausstellung deutsch bestehen Nachweis Feststel...        0
# 13  steuerlich denkmalerhalt Förderprogramm Denkma...        0
# 14  Kanzleipflicht Zulassung Bundesrechtsanwaltsor...        0
# 15  Deutschland Zulassung europäisch Tätigkeit Auf...        0
# 16  Erteilung Zulassung Rechtsanwaltschaft Rechtsa...        0
# 17  Erteilung Zulassung Aufnahme angehöriger Brao ...        0
# 18  Modist Pinselmacher Holzblasinstrumentenmacher...        7
# 19  vereidigen versteigerergewerbe notverkauf sach...        8
#
#                                                 topic
# 0   [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 1   [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 2   [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 3   [grundstück, liegenschaftskataster, grundbuchb...
# 4        [elsteronline, elektronisch, steuerbescheid]
# 5   [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 6   [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 7        [scheidung, scheitern, versorgungsausgleich]
# 8   [räumungsschutzantrag, räumungsschutz, zwangsv...
# 9             [überschuldung, firmenpleit, insolvenz]
# 10  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 11                    [betreiben, straßensex, sexbus]
# 12  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 13  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 14  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 15  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 16  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 17  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 18            [fleischer, handwerksähnlich, löschung]
# 19           [vereidigen, sachverständig, öffentlich]

# %%
df_top_cat["categorized"][7]
# Out:
# [['Weber', 'PersonType', 0.29, 2511],
#  ['Handwerkskammer', 'Location', 0.3, 2747],
#  ['Kraftfahrzeugtechniker', 'Product', 0.34, 151],
#  ['Heizungsbauer', 'Product', 0.36, 567],
#  ['Bürstenmacher', 'PersonType', 0.37, 948],
#  ['Rammgewerbe', 'Product', 0.38, 1589],
#  ['Bäcker', 'PersonType', 0.38, 1743],
#  ['Speiseeishersteller', 'Product', 0.38, 2857],
#  ['holzschindelmach', 'Product', 0.39, 2469],
#  ['Galvaniseur', 'Product', 0.39, 2546],
#  ['Klöppler', 'PersonType', 0.39, 2738],
#  ['Bogenmacher', 'PersonType', 0.4, 279],
#  ['Ausstattungsmaler', 'PersonType', 0.4, 449],
#  ['Fuger', 'PersonType', 0.4, 2825],
#  ['Metallbauer', 'PersonType', 0.41, 1108],
#  ['Karosseriebauer', 'PersonType', 0.41, 2196],
#  ['Steinbildhauer', 'Product', 0.42, 254],
#  ['Baumaschinenmechatroniker', 'Product', 0.42, 1466],
#  ['Kälteanlagenbauer', 'Product', 0.42, 2097],
#  ['Datum', 'Product', 0.42, 2529],
#  ['Kosmetiker', 'Product', 0.42, 2535],
#  ['Handschuhmacher', 'PersonType', 0.42, 2573],
#  ['Kuttler', 'PersonType', 0.43, 97],
#  ['Appreteur', 'Product', 0.43, 727],
#  ['Müller', 'Product', 0.43, 1288],
#  ['Augenoptiker', 'Product', 0.43, 2600],
#  ['Zahntechniker', 'Product', 0.44, 1264],
#  ['Klavierbauer', 'Product', 0.44, 1395],
#  ['Drucker', 'Product', 0.45, 246],
#  ['Brunnenbauer', 'PersonType', 0.45, 467],
#  ['Luftheizungsbauer', 'PersonType', 0.45, 2763],
#  ['Modist', 'Product', 0.46, 0],
#  ['Goldschmied', 'Product', 0.46, 78],
#  ['Büchsenmacher', 'Product', 0.46, 1120],
#  ['Leitermacher', 'PersonType', 0.47, 776],
#  ['Bootsbauer', 'Product', 0.47, 1080],
#  ['Friseur', 'Product', 0.47, 1992],
#  ['Mälzer', 'Product', 0.47, 2282],
#  ['Segelmacher', 'Product', 0.47, 2334],
#  ['Fliesenleger', 'PersonType', 0.47, 2844],
#  ['Informationstechniker', 'Product', 0.48, 589],
#  ['Hörakustiker', 'PersonType', 0.48, 2798],
#  ['Metallgießer', 'PersonType', 0.49, 307],
#  ['Löschung', 'Product', 0.49, 737],
#  ['Pinselmacher', 'Product', 0.5, 7],
#  ['Handwerksroll', 'Skill', 0.5, 1769],
#  ['Raumausstatter', 'PersonType', 0.5, 2613],
#  ['Böttcher', 'Product', 0.5, 2638],
#  ['Maurer', 'PersonType', 0.51, 90],
#  ['Dekateure', 'Product', 0.51, 1213],
#  ['Orgelbauer', 'PersonType', 0.51, 1628],
#  ['Glasveredler', 'PersonType', 0.52, 320],
#  ['Bautenschutzgewerbe', 'Skill', 0.52, 2427],
#  ['Sonnenschutztechniker', 'Product', 0.53, 368],
#  ['Terrazzohersteller', 'Product', 0.53, 1061],
#  ['Medientechnologe', 'Product', 0.53, 1091],
#  ['Handwerksroll', 'Product', 0.53, 1769],
#  ['Konditor', 'Product', 0.53, 1783],
#  ['Werksteinhersteller', 'Product', 0.53, 1811],
#  ['behälterbauer', 'Product', 0.53, 2115],
#  ['textilreinig', 'Product', 0.53, 2129],
#  ['Lampenschirmhersteller', 'PersonType', 0.55, 203],
#  ['Rollladentechniker', 'Product', 0.55, 865],
#  ['Kunststopfer', 'Product', 0.55, 1240],
#  ['Cembalobauer', 'PersonType', 0.55, 1854],
#  ['änderungsschneider', 'Product', 0.56, 47],
#  ['print- Klempner schlagzeugmach', 'Product', 0.56, 1134],
#  ['Schirmmacher', 'Product', 0.56, 1954],
#  ['Buchbinder', 'Product', 0.56, 2289],
#  ['Dachdecker', 'Product', 0.56, 2368],
#  ['Kabelverleger', 'Product', 0.57, 232],
#  ['Flechtwerkgestalter', 'Product', 0.57, 611],
#  ['Maßschneider', 'PersonType', 0.57, 1564],
#  ['Ofenbauer', 'PersonType', 0.57, 1601],
#  ['Lackierer', 'PersonType', 0.57, 1844],
#  ['Wachszieher', 'Product', 0.57, 1867],
#  ['Orthopädieschuhmacher', 'Product', 0.57, 2075],
#  ['vergold', 'Product', 0.57, 2247],
#  ['Modellbauer', 'PersonType', 0.58, 66],
#  ['Fahrzeugbauer', 'PersonType', 0.58, 137],
#  ['Kürschner', 'Product', 0.58, 1278],
#  ['Silberschmied', 'Product', 0.58, 2647],
#  ['flexografen Vulkanisationstechnik', 'Product', 0.59, 1165],
#  ['Posamentierer', 'Product', 0.59, 1199],
#  ['Requisiteure', 'PersonType', 0.59, 1831],
#  ['Schiffbauer', 'PersonType', 0.59, 2457],
#  ['Klavierstimmer', 'Product', 0.59, 2558],
#  ['Muldenhauer', 'PersonType', 0.6, 105],
#  ['Textilgestalter', 'PersonType', 0.6, 291],
#  ['Fleischer', 'Product', 0.6, 2628],
#  ['Tischler', 'Product', 0.6, 2729],
#  ['Elektrotechniker', 'PersonType', 0.61, 1937],
#  ['Kanalreiniger', 'Product', 0.62, 2156],
#  ['Schornsteinfeger', 'PersonType', 0.62, 2781],
#  ['Bestattungsgewerbe', 'Product', 0.63, 649],
#  ['schuhmach', 'Product', 0.64, 269],
#  ['Fotograf', 'PersonType', 0.64, 915],
#  ['Feintäschner', 'Product', 0.64, 1413],
#  ['holzspielzeugmach holzreifenmach', 'Product', 0.64, 2042],
#  ['Stukkateur scharf', 'Product', 0.65, 1321],
#  ['Steinmetz', 'Product', 0.65, 1436],
#  ['Gerber', 'Product', 0.65, 1792],
#  ['Glasapparatebauer', 'Product', 0.65, 2170],
#  ['Drechsler', 'PersonType', 0.65, 2447],
#  ['Stoffmaler', 'Product', 0.65, 2589],
#  ['Straßenbauer', 'PersonType', 0.66, 924],
#  ['Mechaniker', 'PersonType', 0.66, 937],
#  ['Ausbeiner', 'Product', 0.66, 1426],
#  ['Chirurgiemechaniker', 'PersonType', 0.66, 1544],
#  ['Elektromaschinenbauer', 'Product', 0.66, 1658],
#  ['Graveur', 'PersonType', 0.66, 1680],
#  ['Hwk', 'Product', 0.66, 1799],
#  ['Gewerbe', 'Skill', 0.66, 1803],
#  ['asphaltierer', 'PersonType', 0.66, 2831],
#  ['Orthopädietechniker', 'PersonType', 0.67, 117],
#  ['Präzisionswerkzeugmechaniker', 'PersonType', 0.67, 174],
#  ['Textil', 'Product', 0.67, 1054],
#  ['Landmaschinenmechatroniker', 'PersonType', 0.67, 1879],
#  ['Theater brau', 'Product', 0.67, 2321],
#  ['Geigenbauer', 'PersonType', 0.68, 1577],
#  ['Glockengießer', 'Product', 0.68, 2142],
#  ['Sattler', 'Product', 0.68, 2212],
#  ['Holzbildhauer', 'Product', 0.68, 2220],
#  ['maskenbildn', 'Product', 0.68, 2517],
#  ['holzschuhmach', 'Product', 0.68, 2877],
#  ['Maler', 'PersonType', 0.69, 226],
#  ['Gerüstbauer', 'PersonType', 0.69, 356],
#  ['Baufertigteil', 'Product', 0.69, 541],
#  ['Drahtgestelle holzblockmach', 'Product', 0.69, 699],
#  ['innerei-fleischer', 'Product', 0.69, 746],
#  ['Metallbildner', 'Product', 0.69, 1517],
#  ['Daubenhauer', 'Product', 0.69, 1750],
#  ['Holz', 'Product', 0.7, 1408],
#  ['Getränkeleitungsreiniger', 'Product', 0.7, 2486],
#  ['Weinküfer', 'Product', 0.71, 2000],
#  ['Wärmeschutzisolierer', 'Product', 0.71, 2021],
#  ['Harmoniumbauer', 'Product', 0.72, 411],
#  ['Zweiradmechaniker', 'Product', 0.72, 1351],
#  ['Glasbläser zupfinstrumentenmach', 'Product', 0.72, 1695],
#  ['Holzimprägnierung', 'Product', 0.72, 2661],
#  ['Holzblasinstrumentenmacher', 'Product', 0.73, 20],
#  ['Bügelanstalt', 'Product', 0.73, 1295],
#  ['Tankschutzbetrieb', 'Product', 0.73, 2679],
#  ['Mosaikleger', 'Product', 0.74, 764],
#  ['Installateur', 'PersonType', 0.74, 852],
#  ['Metallpolierer', 'Product', 0.74, 2353],
#  ['Edelsteinschleifer', 'Product', 0.74, 2379],
#  ['Plisseebrenner', 'Product', 0.74, 2697],
#  ['theaterkostümnäh', 'Product', 0.74, 2712],
#  ['Apparatebauer', 'PersonType', 0.75, 342],
#  ['dekorationsnäh', 'Product', 0.75, 480],
#  ['Gebäudereiniger', 'Product', 0.75, 884],
#  ['Tankschutzbetreiben', 'Product', 0.75, 1446],
#  ['Feinoptiker', 'Product', 0.75, 2415],
#  ['Fleischzerleger', 'Product', 0.76, 1005],
#  ['Schuhreparatur', 'Product', 0.77, 800],
#  ['Elfenbeinschnitzer', 'Product', 0.77, 1639],
#  ['Betonbauer', 'Product', 0.77, 2010],
#  ['Uhrmacher', 'Product', 0.78, 1021],
#  ['Feinwerkmechaniker', 'PersonType', 0.78, 1906],
#  ['Theaterplastiker', 'Product', 0.78, 2398],
#  ['Schilderhersteller', 'Product', 0.79, 680],
#  ['Porzellanmaler', 'Product', 0.79, 900],
#  ['Korbgestalter', 'Product', 0.79, 962],
#  ['Metallblasinstrumentenmacher', 'Product', 0.79, 976],
#  ['Lichtreklamehersteller', 'Product', 0.79, 1031],
#  ['Stricker', 'Product', 0.79, 2312],
#  ['eisenflecht', 'Product', 0.81, 399],
#  ['estrichleg', 'Product', 0.81, 789],
#  ['metallschleifer', 'Product', 0.81, 815],
#  ['Bodenleger', 'Product', 0.81, 1506],
#  ['keramik', 'Product', 0.81, 2188],
#  ['Fleckteppichhersteller', 'Product', 0.82, 426],
#  ['Bautentrocknungsgewerbe', 'Product', 0.82, 517],
#  ['Sticker', 'Product', 0.82, 581],
#  ['Rohrreiniger', 'Product', 0.82, 1531],
#  ['Seiler', 'Product', 0.82, 2346],
#  ['Zimmerer', 'PersonType', 0.83, 333],
#  ['Metallsägen', 'Product', 0.83, 555],
#  ['Glasanmaler', 'Product', 0.83, 668],
#  ['Teppichreiniger', 'Product', 0.83, 1727],
#  ['Mauerschutz', 'Product', 0.83, 1925],
#  ['Fahrzeugverwerter', 'Product', 0.84, 631],
#  ['Glaser', 'Product', 0.84, 1762],
#  ['Handzuginstrumentenmacher', 'Product', 0.85, 1369],
#  ['Reifentechnik', 'Product', 0.86, 1492],
#  ['Schallschutzisolierer', 'Product', 0.87, 495],
#  ['Kälteschutzisolierer', 'Product', 0.87, 831],
#  ['Metallsäge', 'Product', 0.87, 1253],
#  ['Handdrucker', 'Product', 0.88, 1339],
#  ['Steindrucker', 'Product', 0.89, 2234],
#  ['Betonbohrer', 'Product', 0.89, 2300],
#  ['Plattenleger', 'Product', 0.92, 1308],
#  ['Parkettleger', 'Product', 0.94, 1967],
#  ['Siebdrucker', 'Product', 0.95, 1980]]

# %%
df_top_cat
# Out:
#    cluster                                             lemmas  \
# 0        0  Perso Personalausweisangelegenheit Beantragung...
# 1        1  wissenschaftlich Erwerbstätigkeit arbeitsaufna...
# 2        2  suchen Kur Auskunftserteilung Krankenfürsorg v...
#
#                                        Topics  \
# 0    [ausweis, elektronisch, personalausweis]
# 1   [beschäftigung, arbeitsaufnahm, personal]
# 2  [krankheit, beamte, informationserteilung]
#
#                                          categorized
# 0  [[Wohnung, Location, 0.57, 897], [Tourist, Per...
# 1  [[Personal, PersonType, 0.6, 62], [Mitarbeiter...
# 2  [[Richter, PersonType, 0.59, 55], [beamte, Per...

# %%
df_top_cat
# Out:
#    cluster                                             lemmas  \
# 0        0  Wohngeld mieten Mietzuschuss Wohnhilfe Lastenz...
# 1        1  liegenschaftskatasterauskunft Grundstücksberei...
# 2        2  elektronisch elektronsich einkommensteuertabel...
# 3        3  -- Rechtsanwaltszwang Ehescheidung Scheidung S...
# 4        4  Vollstreckungsschutz Maßnahme Räumungsschutzan...
# 5        5  Geschäftsbetrieb Firmeninsolvenz Unternehmensi...
# 6        6  Erlaubnis Swingerclub Prostschg Bordell Prosti...
# 7        7  Modist Pinselmacher Holzblasinstrumentenmacher...
# 8        8  vereidigen versteigerergewerbe notverkauf sach...
#
#                                               Topics  \
# 0  [antrag, rechtsanwaltschaft, rechtsanwaltsverz...
# 1  [grundstück, liegenschaftskataster, grundbuchb...
# 2       [elsteronline, elektronisch, steuerbescheid]
# 3       [scheidung, scheitern, versorgungsausgleich]
# 4  [räumungsschutzantrag, räumungsschutz, zwangsv...
# 5            [überschuldung, firmenpleit, insolvenz]
# 6                    [betreiben, straßensex, sexbus]
# 7            [fleischer, handwerksähnlich, löschung]
# 8           [vereidigen, sachverständig, öffentlich]
#
#                                          categorized
# 0  [[Wohnung, Location, 0.43, 91], [EU, Location,...
# 1                                                 []
# 2  [[Elster, Location, 0.7, 142], [Finanzamt, Loc...
# 3  [[Ehescheidung, Event, 0.66, 22], [Scheidung, ...
# 4                                                 []
# 5                                                 []
# 6  [[Orgie, Event, 0.4, 158], [Bordellbus, Produc...
# 7  [[Weber, PersonType, 0.29, 2511], [Handwerkska...
# 8  [[Versteigerung, Skill, 0.54, 210], [versteige...

# %%
df_top_cat=categorize_text(df_top)

# %% [markdown]
# Query von ALLEN führt zu cluster 0 für alle
