# %%
import spacy
import pandas as pd
import numpy as np

import Modules.solrhandler as sh
import Modules.clusterer as cls
import Modules.topicdeterminator as td
import Modules.chatbot as cb

import warnings
warnings.filterwarnings(action='ignore')

# %%
#query = "anmeldung"
#target_service = 120686

# %%
# Import eval.csv
import os
file = os.path.realpath("../../Evaluierung/eval.csv")
eval = pd.read_csv(file, sep = ";")
eval = eval.head(1000)
eval.head()
# Out:
#    documentId                              file  dialogId  \
# 0      120697  20220131--quantEvalAllExcel.xlsx         4
# 1      120686  20220131--quantEvalAllExcel.xlsx         4
# 2      329421  20220131--quantEvalAllExcel.xlsx        19
# 3      329421  20220131--quantEvalAllExcel.xlsx        19
# 4      120914  20220131--quantEvalAllExcel.xlsx        23
#
#                                      initialQuestion  suggestionCount  \
# 0                                          Ummeldung                6
# 1                                           Ummelden                6
# 2  Pcr test positiv brauche ich eine Krankschreib...                6
# 3                Quarantäne Krankschreibung vom Arzt                6
# 4                Termin für Zulassung Gebrauchtwagen                6
#
#    directlyFound                                               name
# 0           True                  Änderung/Wechsel der Hauptwohnung
# 1           True                            Anmeldung einer Wohnung
# 2          False  Erstattung nach Infektionsschutzgesetz bei Tät...
# 3           True  Erstattung nach Infektionsschutzgesetz bei Tät...
# 4           True  Zulassung eines Fahrzeuges mit auswärtigem Ken...

# %% [markdown]
# Funktionen

# %%
def findCorrectAnswer(chatbot,targetService):

    # Find Target Cluster
    clusteredColumn = chatbot.clusterer.getClusteredColumn()
    service = chatbot.df.loc[chatbot.df["id"]==str(targetService)]
    if len(service[clusteredColumn].values) == 0:
        return None

    targetCluster = service[clusteredColumn].values[0]

    if targetCluster == chatbot.getSelectedClusterForQuestion():
        return True

    else:
        return False

def getRank(chatbot, targetService):
    temp = chatbot.df#.reset_index()
    rank = temp.index[temp["id"]==str(targetService)].values[0]
    return rank

# %% [markdown]
# Logging

# %%
class Logger:
    
    def __init__(self, chatbot, eval_df):
        self.liste = []
        self.chatbot = chatbot
        self.eval_df = eval_df
    
    def getDataFrame(self): # TODO
        pass
    
    def log(self, ID, t, row, answer = None): 
        target_service = row["documentId"]
        
        dialogId = row["dialogId"]
        file = row["file"]
        
        service_name = row["name"]
        query = row["initialQuestion"]
        
        
        if answer is not None:

            
            nResults = len(self.chatbot.df.index)
            question = self.chatbot.generateQuestion()
            answer = answer

            rank = getRank(self.chatbot,target_service)# getRank(target_service)
            
            row = (file, dialogId, ID, t,  service_name, query, question, answer, rank, nResults)
        else:
            #nInitialResults = len(chatbot.df.index)
            #initialRank = np.nan
            row = (file, dialogId, ID, t, service_name, query, None, None, None, None)
        self.liste.append(row)
        #print(self.liste)

# %% [markdown]
# Execution

# %%
# Initialisierung Komponenten Chatbot
solrhandler = sh.SolrHandler(5)
clusterer = cls.Clusterer()
tpc_dterminator = td.TopicDeterminator()
chatbot = cb.Chatbot(solrhandler,clusterer,tpc_dterminator)

# %%
# Experiment durchlaufen und Loggen
lg = Logger(chatbot,eval)   

for (ID, row) in eval.iterrows():
    
    # fun
    query = row["initialQuestion"]
    target_service = row["documentId"]
    
    # Log
    try:
        chatbot.initialQuery(query)
    except Exception as e:
        if(str(e) == 'response'): # TODO ??
            next
        elif(str(e) == 'no solr output'):
            next
        else:
            print(e)
    
    t = 0
    answer = findCorrectAnswer(chatbot, target_service)
    lg.log(ID,t, row, answer)
    if answer is None:
        continue
    
    
    while not chatbot.refineResultset(answer, recluster = True):
        # log
        t += 1
        
        answer = findCorrectAnswer(chatbot, target_service)
        if answer is None: 
            break
        lg.log(ID, t, row,answer)
# Out:
# 'response'
# 'response'
# 'response'
# 'response'
# 'response'
# 'response'
# 'response'

# %%
#query
#len(solrhandler.get_df_from_query(query))

# %%
log_df = pd.DataFrame(lg.liste, columns=["file","dialogId", "ID","t", "service_name", "query", "question", "answer", "rank", "nResults"])
log_df["rank"] = log_df["rank"]+1
log_df["t"] = log_df["t"] +1
log_df.head()
# Out:
#                                file  dialogId  ID  t  \
# 0  20220131--quantEvalAllExcel.xlsx         4   0  1
# 1  20220131--quantEvalAllExcel.xlsx         4   1  1
# 2  20220131--quantEvalAllExcel.xlsx        19   2  1
# 3  20220131--quantEvalAllExcel.xlsx        19   3  1
# 4  20220131--quantEvalAllExcel.xlsx        23   4  1
#
#                                         service_name  \
# 0                  Änderung/Wechsel der Hauptwohnung
# 1                            Anmeldung einer Wohnung
# 2  Erstattung nach Infektionsschutzgesetz bei Tät...
# 3  Erstattung nach Infektionsschutzgesetz bei Tät...
# 4  Zulassung eines Fahrzeuges mit auswärtigem Ken...
#
#                                                query  \
# 0                                          Ummeldung
# 1                                           Ummelden
# 2  Pcr test positiv brauche ich eine Krankschreib...
# 3                Quarantäne Krankschreibung vom Arzt
# 4                Termin für Zulassung Gebrauchtwagen
#
#                                     question answer  rank  nResults
# 0    Geht es bei ihrem Anliegen um ummelden?   True   3.0       5.0
# 1                                       None   None   NaN       NaN
# 2          Geht es bei ihrem Anliegen um 19?   True   4.0       5.0
# 3  Geht es bei ihrem Anliegen um erstattung?   True   1.0       5.0
# 4                                       None   None   NaN       NaN

# %% [markdown]
# Statistics

# %%
# avg Rank Improvement in turn t
log_df["rank_improvement"] = log_df.groupby(["ID"])["rank"].diff()
log_df.groupby(["t"])["rank_improvement"].mean()
# Out:
# t
# 1         NaN
# 2   -0.602151
# 3   -1.000000
# 4   -1.000000
# Name: rank_improvement, dtype: float64

# %%
# avg nSuggestions Improvement in turn t
log_df["sugg_improvement"] = log_df.groupby(["ID"])["nResults"].diff()
log_df.groupby(["t"])["sugg_improvement"].mean()
# Out:
# t
# 1         NaN
# 2   -1.763441
# 3   -1.000000
# 4   -1.000000
# Name: sugg_improvement, dtype: float64

# %%
# MRR ohne cluster refinement
df = log_df.loc[log_df["t"] == 1]
MRR_ohne = 1/(df["rank"].mean())
MRR_ohne
# Out:
# 0.5629310344827586

# %%
# MRR mit cluster refinement
df = log_df.groupby(["ID"]).last("t")
MRR_mit = 1/(df["rank"].mean())
MRR_mit
#df.head()
# Out:
# 0.6142991533396048

# %%
# avg Turns (Achtun!) -> chatbot geht noch nicht bis auf einzelnen service herunter weil je nachdem alle in einem cluster
print(log_df["t"].mean())

# bei durchschnittlich nResults
print(log_df.groupby(["ID"]).last("t")["nResults"].mean())
# Out:
# 1.162257495590829
# 3.482388973966309

# %%
log_df.head(50)
# Out:
#                                 file  dialogId  ID  t  \
# 0   20220131--quantEvalAllExcel.xlsx         4   0  1
# 1   20220131--quantEvalAllExcel.xlsx         4   1  1
# 2   20220131--quantEvalAllExcel.xlsx        19   2  1
# 3   20220131--quantEvalAllExcel.xlsx        19   3  1
# 4   20220131--quantEvalAllExcel.xlsx        23   4  1
# 5   20220131--quantEvalAllExcel.xlsx        24   5  1
# 6   20220131--quantEvalAllExcel.xlsx        28   6  1
# 7   20220131--quantEvalAllExcel.xlsx        36   7  1
# 8   20220131--quantEvalAllExcel.xlsx        36   7  2
# 9   20220131--quantEvalAllExcel.xlsx        39   8  1
# 10  20220131--quantEvalAllExcel.xlsx        47   9  1
# 11  20220131--quantEvalAllExcel.xlsx        48  10  1
# 12  20220131--quantEvalAllExcel.xlsx        48  11  1
# 13  20220131--quantEvalAllExcel.xlsx        58  12  1
# 14  20220131--quantEvalAllExcel.xlsx        73  13  1
# 15  20220131--quantEvalAllExcel.xlsx        79  14  1
# 16  20220131--quantEvalAllExcel.xlsx        83  15  1
# 17  20220131--quantEvalAllExcel.xlsx        93  16  1
# 18  20220131--quantEvalAllExcel.xlsx        94  17  1
# 19  20220131--quantEvalAllExcel.xlsx        94  18  1
# 20  20220131--quantEvalAllExcel.xlsx        98  19  1
# 21  20220131--quantEvalAllExcel.xlsx       100  20  1
# 22  20220131--quantEvalAllExcel.xlsx       101  21  1
# 23  20220131--quantEvalAllExcel.xlsx       111  22  1
# 24  20220131--quantEvalAllExcel.xlsx       113  23  1
# 25  20220131--quantEvalAllExcel.xlsx       117  24  1
# 26  20220131--quantEvalAllExcel.xlsx       132  25  1
# 27  20220131--quantEvalAllExcel.xlsx       132  26  1
# 28  20220131--quantEvalAllExcel.xlsx       133  27  1
# 29  20220131--quantEvalAllExcel.xlsx       152  28  1
# 30  20220131--quantEvalAllExcel.xlsx       159  29  1
# 31  20220131--quantEvalAllExcel.xlsx       160  30  1
# 32  20220131--quantEvalAllExcel.xlsx       162  31  1
# 33  20220131--quantEvalAllExcel.xlsx       173  32  1
# 34  20220131--quantEvalAllExcel.xlsx       186  33  1
# 35  20220131--quantEvalAllExcel.xlsx       186  34  1
# 36  20220131--quantEvalAllExcel.xlsx       189  35  1
# 37  20220131--quantEvalAllExcel.xlsx       189  36  1
# 38  20220131--quantEvalAllExcel.xlsx       194  37  1
# 39  20220131--quantEvalAllExcel.xlsx       197  38  1
# 40  20220131--quantEvalAllExcel.xlsx       199  39  1
# 41  20220131--quantEvalAllExcel.xlsx       199  40  1
# 42  20220131--quantEvalAllExcel.xlsx       207  41  1
# 43  20220131--quantEvalAllExcel.xlsx       210  42  1
# 44  20220131--quantEvalAllExcel.xlsx       210  42  2
# 45  20220131--quantEvalAllExcel.xlsx       210  42  3
# 46  20220131--quantEvalAllExcel.xlsx       219  43  1
# 47  20220131--quantEvalAllExcel.xlsx       219  43  2
# 48  20220131--quantEvalAllExcel.xlsx       222  44  1
# 49  20220131--quantEvalAllExcel.xlsx       231  45  1
#
#                                          service_name  \
# 0                   Änderung/Wechsel der Hauptwohnung
# 1                             Anmeldung einer Wohnung
# 2   Erstattung nach Infektionsschutzgesetz bei Tät...
# 3   Erstattung nach Infektionsschutzgesetz bei Tät...
# 4   Zulassung eines Fahrzeuges mit auswärtigem Ken...
# 5   Infektionskrankheiten melden - für Gemeinschaf...
# 6                  Impfung gegen Corona (SARS-CoV-2)
# 7                       Meldebescheinigung beantragen
# 8                       Meldebescheinigung beantragen
# 9   Arzneimittel - zur Sachkundeprüfung für den Ha...
# 10  Gaststättengewerbe - zum Unterrichtungsnachwei...
# 11     Coronavirus - Beschaffung von Tests beantragen
# 12     Coronavirus - Beschaffung von Tests beantragen
# 13                               Reisepass beantragen
# 14       Fundsachen - Verlorene Sachen zurückbekommen
# 15  Erstattung nach Infektionsschutzgesetz bei Tät...
# 16     Coronavirus - Beschaffung von Tests beantragen
# 17  Verlust des Personalausweises melden (Verlusta...
# 18                      Impfung - Nebenwirkung melden
# 19                      Impfung - Nebenwirkung melden
# 20                         Führungszeugnis beantragen
# 21                         Personalausweis beantragen
# 22                            Anmeldung einer Wohnung
# 23  Online-Ausweisfunktion (eID) - PIN ändern / ne...
# 24                         Personalausweis beantragen
# 25         Tiere - Gesundheitsbescheinigung für Tiere
# 26               Personalausweis vorläufig beantragen
# 27               Personalausweis vorläufig beantragen
# 28                         Personalausweis beantragen
# 29                      Meldebescheinigung beantragen
# 30  Aufenthaltserlaubnis auf einen neuen Pass über...
# 31                 Impfung gegen Corona (SARS-CoV-2)
# 32     Coronavirus - Beschaffung von Tests beantragen
# 33  Kraftfahrzeug - Wiederzulassung eines länger a...
# 34  Kraftfahrzeug ummelden – nach einem Umzug nach...
# 35  Kraftfahrzeug ummelden – nach einem Umzug nach...
# 36  Namensrechtliche Erklärungen - Erklärung - Ang...
# 37  Namensrechtliche Erklärungen - Erklärung - Ang...
# 38                         Personalausweis beantragen
# 39  Online-Ausweisfunktion (eID) - PIN ändern / ne...
# 40  Beihilfe zu Krankheitskosten - Auskunftserteilung
# 41  Beihilfe zu Krankheitskosten - Auskunftserteilung
# 42                                  Reisepass abholen
# 43                            Beglaubigung von Kopien
# 44                            Beglaubigung von Kopien
# 45                            Beglaubigung von Kopien
# 46                                   Gewerbe anmelden
# 47                                   Gewerbe anmelden
# 48  Personalausweis für in Berlin nicht gemeldete ...
# 49  Erstattung nach Infektionsschutzgesetz bei Tät...
#
#                                                 query  \
# 0                                           Ummeldung
# 1                                            Ummelden
# 2   Pcr test positiv brauche ich eine Krankschreib...
# 3                 Quarantäne Krankschreibung vom Arzt
# 4                 Termin für Zulassung Gebrauchtwagen
# 5   Wo kann ich mich nach Corona Infektion freites...
# 6    Ab wann ist man bei Johnson & Johnson geboostert
# 7                             Genesenen Bescheinigung
# 8                             Genesenen Bescheinigung
# 9   welche medikamente kann man nehmen, wenn man c...
# 10  ab 15.1. ist für Gäste von Restaurants  Nachwe...
# 11  Ich habe mit einem Lateral-Flow-Test positiv g...
# 12     wo kann ich einen kostenlosen PCR-Test machen?
# 13                                   Termin Reisepass
# 14           Ich benötige eine Fundbüro Bescheinigung
# 15  Sehr geehrter Bobbi, wir haben fragen zum Sars...
# 16                Wo ich kann schnell pcr test machen
# 17  wir haben vor wenigen Tagen eine Anzeige erste...
# 18                                                  C
# 19                               Symptome der Impfung
# 20                                    Führungszeugnis
# 21                                    Personalausweis
# 22  Kann ich mich impfen lassen, wenn ich keinen W...
# 23                                            Pin eid
# 24  ich brauche einen vorzugstermin für personalau...
# 25  Wo kann ich einen kostenlosen PCR Test nach po...
# 26                             termin personalausweis
# 27                             termin personalausweis
# 28                        antrag auf eine Blaue Karte
# 29  ich möchte ein Testzentrum eröffnen, wo kann i...
# 30  termin aufenthaltstitel in ein neuen pass über...
# 31                                   Johnson impfpung
# 32                                Termin für pcr-Test
# 33                                Wie lange Isolation
# 34                                      Kfz anmeldung
# 35                                      auto anmelden
# 36                  ich möchte meinen Vornamen ändern
# 37                                     vorname ändern
# 38                             Termin Personalausweis
# 39          pin vom personalausweis neu setzen lassen
# 40                     wie stelle ich online beihilfe
# 41                                  beihilfe online ?
# 42                    reisepass abholen vorzugstermin
# 43  Ich möchte eine beglaubigte Kopie der Geburtur...
# 44  Ich möchte eine beglaubigte Kopie der Geburtur...
# 45  Ich möchte eine beglaubigte Kopie der Geburtur...
# 46              Ich möchte ein klein Gewerbe anmelden
# 47              Ich möchte ein klein Gewerbe anmelden
# 48  Wie bekomme ich ein digitales Genesenenzertifi...
# 49         Wie lange suarNtänd bei positivem pcr test
#
#                                              question answer  rank  nResults  \
# 0             Geht es bei ihrem Anliegen um ummelden?   True   3.0       5.0
# 1                                                None   None   NaN       NaN
# 2                   Geht es bei ihrem Anliegen um 19?   True   4.0       5.0
# 3           Geht es bei ihrem Anliegen um erstattung?   True   1.0       5.0
# 4                                                None   None   NaN       NaN
# 5                                                None   None   NaN       NaN
# 6                                                None   None   NaN       NaN
# 7            Geht es bei ihrem Anliegen um abteilung?  False   1.0       5.0
# 8     Geht es bei ihrem Anliegen um überbeglaubigung?   True   1.0       3.0
# 9                                                None   None   NaN       NaN
# 10                                               None   None   NaN       NaN
# 11               Geht es bei ihrem Anliegen um testv?   True   1.0       1.0
# 12               Geht es bei ihrem Anliegen um testv?   True   1.0       1.0
# 13                Geht es bei ihrem Anliegen um pass?   True   3.0       5.0
# 14           Geht es bei ihrem Anliegen um verlieren?   True   2.0       5.0
# 15                                               None   None   NaN       NaN
# 16               Geht es bei ihrem Anliegen um testv?   True   1.0       1.0
# 17                 Geht es bei ihrem Anliegen um npa?   True   1.0       5.0
# 18                                               None   None   NaN       NaN
# 19              Geht es bei ihrem Anliegen um corona?   True   5.0       5.0
# 20              Geht es bei ihrem Anliegen um strafe?   True   1.0       1.0
# 21                 Geht es bei ihrem Anliegen um npa?   True   2.0       5.0
# 22       Geht es bei ihrem Anliegen um zweitwohnsitz?   True   2.0       5.0
# 23                Geht es bei ihrem Anliegen um chip?   True   1.0       4.0
# 24                 Geht es bei ihrem Anliegen um npa?   True   2.0       5.0
# 25                                               None   None   NaN       NaN
# 26                 Geht es bei ihrem Anliegen um npa?   True   1.0       5.0
# 27                 Geht es bei ihrem Anliegen um npa?   True   1.0       5.0
# 28                                               None   None   NaN       NaN
# 29                                               None   None   NaN       NaN
# 30                Geht es bei ihrem Anliegen um pass?   True   1.0       5.0
# 31                                               None   None   NaN       NaN
# 32               Geht es bei ihrem Anliegen um testv?   True   1.0       1.0
# 33           Geht es bei ihrem Anliegen um zulassung?   True   1.0       1.0
# 34                                               None   None   NaN       NaN
# 35                                               None   None   NaN       NaN
# 36                                               None   None   NaN       NaN
# 37                                               None   None   NaN       NaN
# 38                 Geht es bei ihrem Anliegen um npa?   True   2.0       5.0
# 39               Geht es bei ihrem Anliegen um perso?   True   1.0       5.0
# 40  Geht es bei ihrem Anliegen um beihilfeangelege...   True   1.0       5.0
# 41           Geht es bei ihrem Anliegen um krankheit?   True   1.0       5.0
# 42                Geht es bei ihrem Anliegen um pass?   True   1.0       5.0
# 43         Geht es bei ihrem Anliegen um anerkennung?  False   2.0       5.0
# 44           Geht es bei ihrem Anliegen um zulassung?  False   2.0       3.0
# 45  Geht es bei ihrem Anliegen um zeugnisbeglaubig...   True   1.0       2.0
# 46                 Geht es bei ihrem Anliegen um 34a?  False   1.0       5.0
# 47               Geht es bei ihrem Anliegen um laden?   True   1.0       3.0
# 48                                               None   None   NaN       NaN
# 49                                               None   None   NaN       NaN
#
#     rank_improvement  sugg_improvement
# 0                NaN               NaN
# 1                NaN               NaN
# 2                NaN               NaN
# 3                NaN               NaN
# 4                NaN               NaN
# 5                NaN               NaN
# 6                NaN               NaN
# 7                NaN               NaN
# 8                0.0              -2.0
# 9                NaN               NaN
# 10               NaN               NaN
# 11               NaN               NaN
# 12               NaN               NaN
# 13               NaN               NaN
# 14               NaN               NaN
# 15               NaN               NaN
# 16               NaN               NaN
# 17               NaN               NaN
# 18               NaN               NaN
# 19               NaN               NaN
# 20               NaN               NaN
# 21               NaN               NaN
# 22               NaN               NaN
# 23               NaN               NaN
# 24               NaN               NaN
# 25               NaN               NaN
# 26               NaN               NaN
# 27               NaN               NaN
# 28               NaN               NaN
# 29               NaN               NaN
# 30               NaN               NaN
# 31               NaN               NaN
# 32               NaN               NaN
# 33               NaN               NaN
# 34               NaN               NaN
# 35               NaN               NaN
# 36               NaN               NaN
# 37               NaN               NaN
# 38               NaN               NaN
# 39               NaN               NaN
# 40               NaN               NaN
# 41               NaN               NaN
# 42               NaN               NaN
# 43               NaN               NaN
# 44               0.0              -2.0
# 45              -1.0              -1.0
# 46               NaN               NaN
# 47               0.0              -2.0
# 48               NaN               NaN
# 49               NaN               NaN
