# %%
from topic_determination import Topic_determination

# %%
import spacy

from clustering import Clustering

# %%
nlp = spacy.load('de_core_news_lg')

# %%
clustering = Clustering(nlp)

# %%
df = clustering.run("Antrags", cluster_by="ssdsLemma", do_preprocessing=True, query_max_elems=2000, cluster_eps=1.3, cluster_min_samples=1)
df
# Out:
#        id                                           d115Url  \
# 0  120656  https://service.berlin.de/dienstleistung/120656/
# 1  120665  https://service.berlin.de/dienstleistung/120665/
# 2  325685  https://service.berlin.de/dienstleistung/325685/
# 3  326235  https://service.berlin.de/dienstleistung/326235/
#
#                                             d115Name  \
# 0                 Wohngeld - Mietzuschuss beantragen
# 1               Wohngeld - Lastenzuschuss beantragen
# 2  Einkommensteuer - Festsetzung - Antragsveranla...
# 3  Antragsbescheinigung für Familienangehörige vo...
#
#                                              ssdsAll  d115DocumentBoostValue  \
# 0  [Wohngeld - Mietzuschuss beantragen, Wohngeld ...                1.286952
# 1  [Wohngeld - Lastenzuschuss beantragen, Wohngel...                1.182570
# 2  [Einkommensteuer - Festsetzung - Antragsveranl...                1.000000
# 3  [Antragsbescheinigung für Familienangehörige v...                1.000000
#
#                                      d115Description  \
# 0  Wohngeld kann Ihnen angemessenes und familien-...
# 1  Wohngeld kann Ihnen angemessenes und familien-...
# 2  <strong>Antragsveranlagung</strong><br />\n<br...
# 3  <strong>Bitte beachten Sie</strong>: Diese Die...
#
#                                          d115Synonym  d115Position  \
# 0  [Wohnhilfe, Wohngeldantrag, Lastenzuschuss, Mi...           101
# 1  [Wohnhilfe, Lastenzuschuss, Wohngeld, Wohnung,...           101
# 2  [ELSTER, ELSTEROnline, Lohnsteuerjahresausglei...           101
# 3  [EU, EWR, Freizügigkeit, Freizügigkeitsrecht, ...           101
#
#                                          d115InfoLaw  \
# 0  [{"name":"Wohngeldverordnung (WoGV)","link":"h...
# 1  [{"name":"Wohngeldverordnung (WoGV)","link":"h...
# 2  [{"name":"Einkommensteuer - Durchführungsveror...
# 3  [{"name":"Freizügigkeitsgesetz/EU (FreizügG/EU...
#
#                                    d115Prerequisites  ...  \
# 0  [{"name":"Hauptwohnsitz in Berlin","link":"","...  ...
# 1  [{"name":"Hauptwohnsitz in Berlin","link":"","...  ...
# 2  [{"name":"Einhaltung der Abgabefrist","link":"...  ...
# 3  [{"name":"Aufenthaltskarte soll ausgestellt we...  ...
#
#          ssdsVerrichtungDetailDict  \
# 0    [Antragsannahme Mietzuschuss]
# 1  [Antragsannahme Lastenzuschuss]
# 2                              NaN
# 3                              NaN
#
#                                          ssdsSynonym  \
# 0  [Wohnhilfe, Wohngeldantrag, Lastenzuschuss, Mi...
# 1  [Wohnhilfe, Lastenzuschuss, Wohngeld, Wohnung,...
# 2  [Einkommensteuerausgleich, ELSTER, ELSTEROnlin...
# 3  [EU, EWR, Freizügigkeit, Freizügigkeitsrecht, ...
#
#                                      ssdsSynonymDict  \
# 0  [Wohnhilfe, Wohngeldantrag, Lastenzuschuss, Mi...
# 1  [Wohnhilfe, Lastenzuschuss, Wohngeld, Wohnung,...
# 2  [Einkommensteuerausgleich, ELSTER, ELSTEROnlin...
# 3  [EU, EWR, Freizügigkeit, Freizügigkeitsrecht, ...
#
#                                   ssdsManualKeywords            _version_  \
# 0                                   [Wohngeldantrag]  1727918339437625344
# 1                                   [Wohngeldantrag]  1727918339453353984
# 2  [Einkommenssteuer, Steuererklärung, Einkommens...  1727918340964352000
# 3                                                NaN  1727918341312479232
#
#                                      d115ProcessTime  \
# 0                                                NaN
# 1                                                NaN
# 2  Mit den Berliner Finanzämtern ist vereinbart, ...
# 3                                                NaN
#
#                                            leikaName  \
# 0                                                NaN
# 1                                                NaN
# 2                        Einkommensteuer Festsetzung
# 3  Bescheinigung über die Einreichung des Antrags...
#
#                                         leikaSynonym  \
# 0                                                NaN
# 1                                                NaN
# 2  [Einkommensteuer, Einkommensteuerausgleich, Ei...
# 3                                                NaN
#
#                                  ssdsLemma_processed ssdsLemma_cluster
# 0  wohngeld mieten mietzuschuss wohnhilfe lastenz...                 0
# 1  wohngeld mieten eigenheimhilfe lastenzuschuss ...                 0
# 2  elektronisch elektronsich einkommensteuertabel...                 1
# 3  freizügigkeitsrecht ewr aufenthaltskart freizü...                 2
#
# [4 rows x 45 columns]

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon May 23 15:26:10 2022

@author: D073079
"""

import pandas as pd

import numpy as np
import scipy
from sklearn.feature_extraction.text import TfidfVectorizer
from operator import itemgetter
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

class Topic_determination:
    
    def __init__(self):
        self.df_clus= None
        self.df = None
        self.client = None
        
    def run(self, df, top_n=1, clustered_by="ssdsLemma",categorize_key="False"):        
        
        """
            Takes the Dataframe from Clustering, and returns, enriched by the
            topics of the clusters
            Parameter:     
                df Dataframe in format from clustering
                top_n Number of TOpics (from TfIdf) thats sent back
                clustered_by column by which was clustered in clustering
                categorized_key if "False", doesnt use categorizing, otherwise set the key
            Return:
                df + 
                "Topics"(List of words best describing cluster (after Tfidf))
                "categorized" Per Array List of (Word, Category, Score, Offset)
            
        """
        self.df= None
        self.df_clus=None
        self.client = None
        self.df=df
        self.group_by_cluster(clustered_by)
        self.return_topics(top_n,clustered_by)
        if(categorize_key!="False"):            
            self.categorize_text(key=categorize_key,endpoint="https://berlinbobbi.cognitiveservices.azure.com/",col_name="ssdsLemma")
        self.topics_to_service(clustered_by)
        return self.df
        
    def group_by_cluster(self,col_name="ssdsLemma"):
        df_work = self.df[[f"{col_name}_processed",f"{col_name}_cluster"]]
        df_work=df_work.groupby([f"{col_name}_cluster"])[f"{col_name}_processed"].apply(lambda x: ' '.join(x)).reset_index()
        self.df_clus=df_work
    
    def return_topics(self,n=1,col_name="ssdsLemma"):
        vectorizer=TfidfVectorizer()
        rows = vectorizer.fit_transform(self.df_clus[f"{col_name}_processed"].tolist()).toarray()
        features=vectorizer.get_feature_names()
        i=0
        topics=[]
        while i<len(rows):
            top_feats=[]
            topn_ids = np.argsort(rows[i])[::-1][:n]
            top_feats = [(features[j]) for j in topn_ids]
            topics.append(top_feats)
            i+=1
        self.df_clus['Topics']=topics        
    
    def topics_to_service(self,col_name="ssdsLemma"):
        self.df["Topics"]=self.df.apply(lambda row: self.df_clus.iloc[self.df[f"{col_name}_cluster"].iloc[row.name],2], axis=1)
        if 'categorized' in self.df_clus:
            self.df["categorized"]=self.df.apply(lambda row: self.df_clus.iloc[self.df[f"{col_name}_cluster"].iloc[row.name],3], axis=1)
        
    def authenticate_azure_client(self,key,endpoint="https://berlinbobbi.cognitiveservices.azure.com/"):
        ta_credential = AzureKeyCredential(key)
        text_analytics_client = TextAnalyticsClient(endpoint=endpoint, 
        credential=ta_credential)
        self.client = text_analytics_client   
    
    def categorize_text(self,key,endpoint="https://berlinbobbi.cognitiveservices.azure.com/",col_name="ssdsLemma"):
        self.authenticate_azure_client(key,endpoint)        
        topic=[None]*len(self.df_clus)
        i=0
        while i<len(self.df_clus):            
            documents=[self.df_clus[f"{col_name}_processed"].iloc[i][0:5119]]    
            result =self.client.recognize_entities(documents)[0]
            summary=[]       
            for entity in result.entities:
                categorized=[entity.text,entity.category,round(entity.confidence_score,2),entity.offset]
                summary.append(categorized)
            topic[i]=(sorted(summary,key=itemgetter(3),reverse=False))
            i+=1
        self.df_clus['categorized']=topic

# %%
topic_determination=Topic_determination()

# %%
df_res=topic_determination.run(df,1,"ssdsLemma")
df_res

# %%
df_t=topic_determination.run(df,1,"ssdsLemma","False")
df_t
# Out:
#        id                                           d115Url  \
# 0  120656  https://service.berlin.de/dienstleistung/120656/
# 1  120665  https://service.berlin.de/dienstleistung/120665/
# 2  325685  https://service.berlin.de/dienstleistung/325685/
# 3  326235  https://service.berlin.de/dienstleistung/326235/
#
#                                             d115Name  \
# 0                 Wohngeld - Mietzuschuss beantragen
# 1               Wohngeld - Lastenzuschuss beantragen
# 2  Einkommensteuer - Festsetzung - Antragsveranla...
# 3  Antragsbescheinigung für Familienangehörige vo...
#
#                                              ssdsAll  d115DocumentBoostValue  \
# 0  [Wohngeld - Mietzuschuss beantragen, Wohngeld ...                1.286952
# 1  [Wohngeld - Lastenzuschuss beantragen, Wohngel...                1.182570
# 2  [Einkommensteuer - Festsetzung - Antragsveranl...                1.000000
# 3  [Antragsbescheinigung für Familienangehörige v...                1.000000
#
#                                      d115Description  \
# 0  Wohngeld kann Ihnen angemessenes und familien-...
# 1  Wohngeld kann Ihnen angemessenes und familien-...
# 2  <strong>Antragsveranlagung</strong><br />\n<br...
# 3  <strong>Bitte beachten Sie</strong>: Diese Die...
#
#                                          d115Synonym  d115Position  \
# 0  [Wohnhilfe, Wohngeldantrag, Lastenzuschuss, Mi...           101
# 1  [Wohnhilfe, Lastenzuschuss, Wohngeld, Wohnung,...           101
# 2  [ELSTER, ELSTEROnline, Lohnsteuerjahresausglei...           101
# 3  [EU, EWR, Freizügigkeit, Freizügigkeitsrecht, ...           101
#
#                                          d115InfoLaw  \
# 0  [{"name":"Wohngeldverordnung (WoGV)","link":"h...
# 1  [{"name":"Wohngeldverordnung (WoGV)","link":"h...
# 2  [{"name":"Einkommensteuer - Durchführungsveror...
# 3  [{"name":"Freizügigkeitsgesetz/EU (FreizügG/EU...
#
#                                    d115Prerequisites  ...  \
# 0  [{"name":"Hauptwohnsitz in Berlin","link":"","...  ...
# 1  [{"name":"Hauptwohnsitz in Berlin","link":"","...  ...
# 2  [{"name":"Einhaltung der Abgabefrist","link":"...  ...
# 3  [{"name":"Aufenthaltskarte soll ausgestellt we...  ...
#
#                                          ssdsSynonym  \
# 0  [Wohnhilfe, Wohngeldantrag, Lastenzuschuss, Mi...
# 1  [Wohnhilfe, Lastenzuschuss, Wohngeld, Wohnung,...
# 2  [Einkommensteuerausgleich, ELSTER, ELSTEROnlin...
# 3  [EU, EWR, Freizügigkeit, Freizügigkeitsrecht, ...
#
#                                      ssdsSynonymDict  \
# 0  [Wohnhilfe, Wohngeldantrag, Lastenzuschuss, Mi...
# 1  [Wohnhilfe, Lastenzuschuss, Wohngeld, Wohnung,...
# 2  [Einkommensteuerausgleich, ELSTER, ELSTEROnlin...
# 3  [EU, EWR, Freizügigkeit, Freizügigkeitsrecht, ...
#
#                                   ssdsManualKeywords            _version_  \
# 0                                   [Wohngeldantrag]  1727918339437625344
# 1                                   [Wohngeldantrag]  1727918339453353984
# 2  [Einkommenssteuer, Steuererklärung, Einkommens...  1727918340964352000
# 3                                                NaN  1727918341312479232
#
#                                      d115ProcessTime  \
# 0                                                NaN
# 1                                                NaN
# 2  Mit den Berliner Finanzämtern ist vereinbart, ...
# 3                                                NaN
#
#                                            leikaName  \
# 0                                                NaN
# 1                                                NaN
# 2                        Einkommensteuer Festsetzung
# 3  Bescheinigung über die Einreichung des Antrags...
#
#                                         leikaSynonym  \
# 0                                                NaN
# 1                                                NaN
# 2  [Einkommensteuer, Einkommensteuerausgleich, Ei...
# 3                                                NaN
#
#                                  ssdsLemma_processed  ssdsLemma_cluster  \
# 0  wohngeld mieten mietzuschuss wohnhilfe lastenz...                  0
# 1  wohngeld mieten eigenheimhilfe lastenzuschuss ...                  0
# 2  elektronisch elektronsich einkommensteuertabel...                  1
# 3  freizügigkeitsrecht ewr aufenthaltskart freizü...                  2
#
#              Topics
# 0  [lastenzuschuss]
# 1  [lastenzuschuss]
# 2    [elektronisch]
# 3          [bürger]
#
# [4 rows x 46 columns]

# %%
df_t

# %%
print(df_t)
# Out:
# None

# %%
sys.stdout.flush()

# %%
import sys

# %%
print(df_t["ssdsLemma"].iloc[3])
# Out:
# ['liegenschaftskatasterauskunft', 'grundstücksbereinigung', 'vereinigung', 'liegenschaftskataster', '(', ')', 'und', 'grundstück', '-', 'vereinigungsantrag', 'beglaubigung', 'vereinigungs-', 'grundbuchbereinigung', 'teilungsantrag', 'teilung', 'verschmelzung']

# %%
df_t[["d115Name","Topics"]]
# Out:
#                                              d115Name                  Topics
# 0                  Wohngeld - Mietzuschuss beantragen              [wohngeld]
# 1                Wohngeld - Lastenzuschuss beantragen              [wohngeld]
# 2   Ehefähigkeitszeugnis – Beratung, Antrag,  Auss...         [eheschließung]
# 3   Vereinigungs- und Teilungsanträge (Grundstücke...            [grundstück]
# 4   Einkommensteuer - Festsetzung - Antragsveranla...          [elsteronline]
# 5           Sozialversicherung - Rentenantrag stellen                 [rente]
# 6   Antragsbescheinigung für Familienangehörige vo...                [bürger]
# 7                     Scheidungsantrag - Entscheidung             [scheidung]
# 8   Vollstreckungsschutzantrag, Spezialfall Räumun...  [räumungsschutzantrag]
# 9   Insolvenzverfahren - Regelinsolvenz - Geschäft...         [überschuldung]
# 10  Tätigkeiten mit Krankheitserregern - Beantragu...           [beantragung]
# 11   Prostitutionsgewerbe - Erlaubnis für den Betrieb             [betreiben]
# 12          Staatsangehörigkeitsausweis - Ausstellung               [deutsch]
# 13  Denkmal - Bescheinigung für Denkmalerhalt nach...         [denkmalerhalt]
# 14              Kanzleipflicht - Antrag auf Befreiung    [rechtsanwaltschaft]
# 15  Europäischer Rechtsanwalt - Antrag auf Aufnahm...    [rechtsanwaltschaft]
# 16          Rechtsanwaltschaft - Antrag auf Zulassung    [rechtsanwaltschaft]
# 17  Rechtsanwaltschaft - Antrag auf Aufnahme als A...    [rechtsanwaltschaft]
# 18  Handwerk – Löschung aus der Handwerksrolle, de...             [fleischer]
# 19  Versteigerergewerbe - Öffentliche Bestellung u...            [vereidigen]
