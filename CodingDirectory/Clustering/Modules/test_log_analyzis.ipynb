# %%
import solrhandler as sh
import clusterer as cls
import topicdeterminator as td
import keyword_check as kw_ch
import log_analyzer as lo_an
import math
import statistics
#import numpy as np
import pandas as pd

solrhandler = sh.SolrHandler(1000)
clusterer = cls.Clusterer()
tpc_dterminator = td.TopicDeterminator()
#activ_chatbot = kw_ch.Keyword_check(sh.SolrHandler,cls.Clusterer,td.TopicDeterminator,"antrag",3)


from keywords_evaluation import *

key_eval=Keywords_eval(sh.SolrHandler,cls.Clusterer,td.TopicDeterminator,kw_ch.Keyword_check,"antrag",3,False)
key_eval_clus=Keywords_eval(sh.SolrHandler,cls.Clusterer,td.TopicDeterminator,kw_ch.Keyword_check,"antrag",3,True)

# %%
key_eval_clus=Keywords_eval(sh.SolrHandler,cls.Clusterer,td.TopicDeterminator,kw_ch.Keyword_check,"antrag",3,True)

# %%
# Import eval.csv
import os
file = os.path.realpath("../../../Evaluierung/eval.csv")
eval = pd.read_csv(file, sep = ";")
eval = eval.head(1000)
eval.head()
df=eval[0:250]

# %%
logs=key_eval.initialize_evaluation(df)
log_analyzer=lo_an.Log_Analyzer(logs)
delta,services,questions,means=log_analyzer.run_it()
# Out:
# 'response'
# 'response'
# 'response'
# 'response'

# %%
logs_clus=key_eval.initialize_evaluation(df)
log_analyzer_clus=lo_an.Log_Analyzer(logs)
delta_clus,services_clus,questions_clus,means_clus=log_analyzer.run_it()
# Out:
# 'response'
# 'response'
# 'response'
# 'response'

# %%
means
# Out:
# {'Mean Turns': 2.61340206185567,
#  'Mean nResults Reduct': 0.43497464961701465,
#  'Mean delta nResults': 8.833333333333334,
#  'Mean delta Rank': 0.6125211505922166}

# %%
means_clus
# Out:
# {'Mean Turns': 2.61340206185567,
#  'Mean nResults Reduct': 0.43497464961701465,
#  'Mean delta nResults': 8.833333333333334,
#  'Mean delta Rank': 0.6125211505922166}

# %%
logs
# Out:
#                                 file  dialogId  ID  t  \
# 0   20220131--quantEvalAllExcel.xlsx       199   0  0
# 1   20220131--quantEvalAllExcel.xlsx       199   0  1
# 2   20220131--quantEvalAllExcel.xlsx       199   0  2
# 3   20220131--quantEvalAllExcel.xlsx       199   0  3
# 4   20220131--quantEvalAllExcel.xlsx       199   0  4
# ..                               ...       ...  .. ..
# 62  20220131--quantEvalAllExcel.xlsx       294  19  1
# 63  20220131--quantEvalAllExcel.xlsx       294  19  2
# 64  20220131--quantEvalAllExcel.xlsx       294  19  3
# 65  20220131--quantEvalAllExcel.xlsx       294  19  4
# 66  20220131--quantEvalAllExcel.xlsx       294  19  5
#
#                                                  name  \
# 0   Beihilfe zu Krankheitskosten - Auskunftserteilung
# 1   Beihilfe zu Krankheitskosten - Auskunftserteilung
# 2   Beihilfe zu Krankheitskosten - Auskunftserteilung
# 3   Beihilfe zu Krankheitskosten - Auskunftserteilung
# ...

# %%
logs_clus
# Out:
#                                 file  dialogId  ID  t  \
# 0   20220131--quantEvalAllExcel.xlsx       199   0  0
# 1   20220131--quantEvalAllExcel.xlsx       199   0  1
# 2   20220131--quantEvalAllExcel.xlsx       199   0  2
# 3   20220131--quantEvalAllExcel.xlsx       199   0  3
# 4   20220131--quantEvalAllExcel.xlsx       199   0  4
# ..                               ...       ...  .. ..
# 62  20220131--quantEvalAllExcel.xlsx       294  19  1
# 63  20220131--quantEvalAllExcel.xlsx       294  19  2
# 64  20220131--quantEvalAllExcel.xlsx       294  19  3
# 65  20220131--quantEvalAllExcel.xlsx       294  19  4
# 66  20220131--quantEvalAllExcel.xlsx       294  19  5
#
#                                                  name  \
# 0   Beihilfe zu Krankheitskosten - Auskunftserteilung
# 1   Beihilfe zu Krankheitskosten - Auskunftserteilung
# 2   Beihilfe zu Krankheitskosten - Auskunftserteilung
# 3   Beihilfe zu Krankheitskosten - Auskunftserteilung
# ...

# %%
questions

# %%
questions_clus
# Out:
#                                  file  dialogId  ID  t  \
# 0    20220131--quantEvalAllExcel.xlsx         4   0  0
# 1    20220131--quantEvalAllExcel.xlsx         4   0  1
# 2    20220131--quantEvalAllExcel.xlsx        19   2  0
# 3    20220131--quantEvalAllExcel.xlsx        19   2  1
# 4    20220131--quantEvalAllExcel.xlsx        19   2  2
# ..                                ...       ...  .. ..
# 501  20220131--quantEvalAllExcel.xlsx       294  19  1
# 502  20220131--quantEvalAllExcel.xlsx       294  19  2
# 503  20220131--quantEvalAllExcel.xlsx       294  19  3
# 504  20220131--quantEvalAllExcel.xlsx       294  19  4
# 505  20220131--quantEvalAllExcel.xlsx       294  19  5
#
#                                                   name  \
# 0                    Änderung/Wechsel der Hauptwohnung
# 1                    Änderung/Wechsel der Hauptwohnung
# 2    Erstattung nach Infektionsschutzgesetz bei Tät...
# 3    Erstattung nach Infektionsschutzgesetz bei Tät...
# ...

# %%
means
# Out:
# {'Mean Turns': 2.4827586206896552,
#  'Mean nResults Reduct': 0.4396321154358798,
#  'Mean delta nResults': 9.045027214250371,
#  'Mean delta Rank': 0.7822859970311727}

# %%
questions
# Out:
#                                                     Dialog_Count  \
# question
# Geht es bei Ihrem Anliegen um 13c?                             1
# Geht es bei Ihrem Anliegen um 14?                              2
# Geht es bei Ihrem Anliegen um 15?                              2
# Geht es bei Ihrem Anliegen um 18?                              3
# Geht es bei Ihrem Anliegen um 19?                            187
# ...                                                          ...
# Geht es bei Ihrem Anliegen um wohnung?                         1
# Geht es bei Ihrem Anliegen um zulassung?                      23
# Geht es bei Ihrem Anliegen um zulassungsbeschei...             8
# Geht es bei Ihrem Anliegen um änderung?                        3
# initialQuery                                                 735
#
#                                                     Services_Count  \
# question
# Geht es bei Ihrem Anliegen um 13c?                               1
# ...

# %%
services
# Out:
#                                                     Count_Turns  Min_Turns  \
# name
# Abmeldung einer Wohnung                                       9          2
# Anerkennung ausländischer Berufsqualifikationen...            1          1
# Anmeldung einer Wohnung                                      54          0
# Approbation als Arzt - Erteilung - wenn Ärztlic...            1          2
# Aufenthaltserlaubnis auf einen neuen Pass übert...            4          5
# ...                                                         ...        ...
# Zweitwohnungsteuer bezahlen                                   1          4
# berlinpass verlängern                                         2          1
# elektronischer Aufenthaltstitel (eAT) - Ausgabe               2          5
# elektronischer Aufenthaltstitel (eAT) - Verlust...            1          3
# Änderung/Wechsel der Hauptwohnung                            24          1
#
# ...
