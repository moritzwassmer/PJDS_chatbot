# %%
from keyword_check import Keyword_check

import math
import statistics
#import numpy as np
import pandas as pd

from keyword_check import *

keywords=Keyword_check()

from keywords_evaluation import *

key_eval=Keywords_eval()

# %%
# Import eval.csv
import os
file = os.path.realpath("../../../Evaluierung/eval.csv")
eval = pd.read_csv(file, sep = ";")
eval = eval.head(1000)
eval.head()
df=eval[20:40]

# %%
logs=key_eval.initialize_evaluation(df)
# Out:
# 0
# 14
# 5
# 3
# 2
# 1
# 9
# 5
# 3
# 1
# 2
# 2
# 3
# 14
# 5
# 3
# 2
# 4
# 5
# 14
# 5
# 3
# 2
# 6
# 14
# 5
# 3
# 2
# 7
# 15
# 5
# 3
# 2
# 8
# 9
# 46
# 30
# 10
# 5
# 3
# 2
# 10
# Empty query result!
# 11
# 1
# 12
# 1
# 13
# 37
# 18
# 8
# 4
# 2
# 14
# 37
# 18
# 8
# 4
# 2
# 15
# 16
# 17
# 14
# 5
# 3
# 2
# 18
# 43
# 13
# 6
# 3
# 1
# 19
# 29
# 23
# 17
# 12
# 8
# 2
# [100, 100, 100, 100, 101, 101, 101, 101, 111, 113, 113, 113, 113, 132, 132, 132, 132, 132, 132, 132, 132, 133, 133, 133, 133, 159, 159, 159, 159, 159, 159, 162, 173, 186, 186, 186, 186, 186, 186, 186, 186, 186, 186, 194, 194, 194, 194, 197, 197, 197, 197, 197, 199, 199, 199, 199, 199, 199]
# 58

# %%
logs
# Out:
#                                 file  dialogId  ID  t  \
# 0   20220131--quantEvalAllExcel.xlsx       100   0  1
# 1   20220131--quantEvalAllExcel.xlsx       100   0  2
# 2   20220131--quantEvalAllExcel.xlsx       100   0  3
# 3   20220131--quantEvalAllExcel.xlsx       100   0  4
# 4   20220131--quantEvalAllExcel.xlsx       101   1  1
# 5   20220131--quantEvalAllExcel.xlsx       101   1  2
# 6   20220131--quantEvalAllExcel.xlsx       101   1  3
# 7   20220131--quantEvalAllExcel.xlsx       101   1  4
# 8   20220131--quantEvalAllExcel.xlsx       111   2  1
# 9   20220131--quantEvalAllExcel.xlsx       113   3  1
# 10  20220131--quantEvalAllExcel.xlsx       113   3  2
# 11  20220131--quantEvalAllExcel.xlsx       113   3  3
# 12  20220131--quantEvalAllExcel.xlsx       113   3  4
# 13  20220131--quantEvalAllExcel.xlsx       132   5  1
# 14  20220131--quantEvalAllExcel.xlsx       132   5  2
# 15  20220131--quantEvalAllExcel.xlsx       132   5  3
# ...

# %%
pd.concat(df,df.iloc[1,:])
