# %%
import spacy

from clustering import Clustering

# %%
nlp = spacy.load('de_core_news_lg')

# %%
clustering = Clustering(nlp)

# %%
df = clustering.run("%3A", cluster_by="ssdsLemma", do_preprocessing=True, query_max_elems=2000, cluster_eps=1.3, cluster_min_samples=1)
df
# Out:
#          id                                           d115Url  \
# 0    120335  https://service.berlin.de/dienstleistung/120335/
# 1    120656  https://service.berlin.de/dienstleistung/120656/
# 2    120658  https://service.berlin.de/dienstleistung/120658/
# 3    120665  https://service.berlin.de/dienstleistung/120665/
# 4    120671  https://service.berlin.de/dienstleistung/120671/
# ..      ...                                               ...
# 876  330794  https://service.berlin.de/dienstleistung/330794/
# 877  330848  https://service.berlin.de/dienstleistung/330848/
# 878  330863  https://service.berlin.de/dienstleistung/330863/
# 879  330869  https://service.berlin.de/dienstleistung/330869/
# 880  330875  https://service.berlin.de/dienstleistung/330875/
#
#                                               d115Name  \
# 0                              Abmeldung einer Wohnung
# 1                   Wohngeld - Mietzuschuss beantragen
# ...
